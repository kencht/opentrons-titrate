# %%
import itertools
import math
from itertools import islice
from pprint import pprint

import numpy as np
import opentrons.simulate

protocol = opentrons.simulate.get_protocol_api("2.12")
protocol.home()

# %run opentrons_titrate_functions.ipynb
# Out:
# /Users/timkench/.opentrons/robot_settings.json not found. Loading defaults
# /Users/timkench/.opentrons/deck_calibration.json not found. Loading defaults

# %%
tiprack_20a = protocol.load_labware("opentrons_96_tiprack_20ul", location="7")
tiprack_20b = protocol.load_labware("opentrons_96_tiprack_20ul", location="8")
tiprack_20c = protocol.load_labware("opentrons_96_tiprack_20ul", location="9")

tiprack_300a = protocol.load_labware("opentrons_96_tiprack_300ul", location="10")
tiprack_300b = protocol.load_labware("opentrons_96_tiprack_300ul", location="11")

m20 = protocol.load_instrument(
    "p20_multi_gen2", "left", tip_racks=[tiprack_20a, tiprack_20b, tiprack_20c]
)
m300 = protocol.load_instrument(
    "p300_multi_gen2", "right", tip_racks=[tiprack_300a, tiprack_300b]
)

labware_96w_200ul = "biorad_96_wellplate_200ul_pcr"
labware_12w_22ml = "nest_96_wellplate_2ml_deep"
labware_384w_20ul = "appliedbiosystemsmicroamp_384_wellplate_40ul"

res_plate_ot = protocol.load_labware(labware_12w_22ml, "1")
stock_plate_ot = protocol.load_labware(labware_96w_200ul, "2")
dil_plate_ot = protocol.load_labware(labware_96w_200ul, "3")
measure_plate_1_ot = protocol.load_labware(labware_96w_200ul, "4")
measure_plate_2_ot = protocol.load_labware(labware_96w_200ul, "5")

measure_plates_ot = [measure_plate_1_ot, measure_plate_2_ot]

# %%
# set up plates

res_plate = ResPlate(reagents={'buffer':0}, active_cols=(1,5))
res_plate.assign_ot(res_plate_ot)

stock_plate = GeneralPlate(active_cols=0, start_conc = 1000, start_vol = 2)
stock_plate.assign_ot(stock_plate_ot)

dil_plate = GeneralPlate(map_to = stock_plate, end_conc = 4, end_vol = 300)
dil_plate.assign_ot(dil_plate_ot)
dil_plate.make_transfer_map()

measure_plate = MeasurePlate(map_to = res_plate, points=6)
measure_plate.assign_ots(measure_plates_ot)
measure_plate.make_transfer_map()

# set up pipettes and protocol

m20_c = CustomPipette(m20, name="m20_c")
m300_c = CustomPipette(m300, name="m300_c")

CP = CustomProtocol(
    solvent_location=res_plate.reagents["buffer"], m20=m20_c, m300=m300_c
)

# do titration

CP.add(plate=stock_plate, vol=200)
CP.dilution(start_plate=stock_plate, end_plate=dil_plate)
CP.serial_dilute(plate=measure_plate, vol=40, sd_factor=0.5)
CP.add(plate=measure_plate, vol=40, source=dil_plate.cols[0], top_dispense='Yes')
# Out:
# This will add the specified source to the active columns of the plate using the m300_c pipette.
# The plate will be diluted to 10.0 µM
# Do you want to continue? (Y/N):  y
# continuing...
# done
# plate diluted to 10.0 µM
# This will transfer 120.0 µL and combine it with 180.0 µL of solvent for a end concentration of 4 µM.
# Do you want to continue? (Y/N):  y
# continuing...
# done
# This will use the transfer map of the specified plate to carry out a serial dilution using the m300_c pipette.
# Do you want to continue? (Y/N):  y
# continuing...
# done
# This will add the specified source to the active columns of the plate using the m300_c pipette.
# Do you want to continue? (Y/N):  y
# continuing...
# done

# %%
for line in protocol.commands():
    print(line)
# Out:
# Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 216.0 uL from A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 200.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A2 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 194.4 uL from A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 180.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A3 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Dispensing 30.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 470.0 uL/sec
# Aspirating 120.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 2
# Dispensing 120.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Aspirating 150.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Dispensing 150.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Dispensing 30.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 470.0 uL/sec
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A4 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 259.2 uL from A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 40.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 48.0 uL into A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Aspirating 259.2 uL from A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 40.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 40.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 48.0 uL into A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Aspirating 259.2 uL from A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 40.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 48.0 uL into A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Aspirating 259.2 uL from A1 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 40.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 40.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A5 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 80.0 uL from A2 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A2 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A6 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 80.0 uL from A3 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A3 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Dispensing 16.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A7 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 80.0 uL from A4 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A4 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A8 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 80.0 uL from A5 of NEST 96 Deep Well Plate 2mL on 1 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A5 of NEST 96 Deep Well Plate 2mL on 1
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 80.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Dispensing 16.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 470.0 uL/sec
# Aspirating 80.0 uL from A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5
# Dropping tip into A1 of Opentrons Fixed Trash on 12
# Picking up tip from A9 of Opentrons 96 Tip Rack 300 µL on 10
# Aspirating 259.2 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Dispensing 40.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 48.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Aspirating 259.2 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Dispensing 40.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 4 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 48.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Aspirating 259.2 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Dispensing 40.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A2 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A3 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A4 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A5 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A6 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 48.0 uL into A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Aspirating 259.2 uL from A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Moving to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 3
# Dispensing 40.0 uL into A7 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A8 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A9 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A10 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A11 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dispensing 40.0 uL into A12 of Bio-Rad 96 Well Plate 200 µL PCR on 5 at 94.0 uL/sec
# Delaying for 0 minutes and 0.0 seconds
# Dropping tip into A1 of Opentrons Fixed Trash on 12
